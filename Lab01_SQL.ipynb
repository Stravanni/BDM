# %% [markdown]
# <a href="https://colab.research.google.com/github/Stravanni/BDM/blob/main/Lab01_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
from datetime import datetime, timedelta
import random
import pandas as pd

# %%
import sqlite3
from datetime import datetime, timedelta
import random

# Connect to SQLite database (creates a new database if it doesn't exist)
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# Create tables
cursor.execute("""
CREATE TABLE CUSTOMER (
    NAME TEXT,
    CITY TEXT,
    REGION TEXT,
    COUNTRY TEXT,
    PHONE TEXT,
    PRIMARY KEY (NAME, CITY)
)
""")

cursor.execute("""
CREATE TABLE PRODUCT (
    PROD_CODE TEXT PRIMARY KEY,
    PRICE REAL,
    PROD_TYPE TEXT,
    QUANTITY INTEGER
)
""")

cursor.execute("""
CREATE TABLE PURCHASE (
    CUSTOMER_NAME TEXT,
    CUSTOMER_CITY TEXT,
    PURCHASE_DATE DATE,
    PROD_CODE TEXT NOT NULL,
    FOREIGN KEY (CUSTOMER_NAME, CUSTOMER_CITY) REFERENCES CUSTOMER(NAME, CITY),
    FOREIGN KEY (PROD_CODE) REFERENCES PRODUCT(PROD_CODE)
)
""")

# Sample data for CUSTOMER (including Italian customers)
customers = [
    ('John Doe', 'New York', 'NY', 'USA', '1234567890'),
    ('Jane Smith', 'Los Angeles', 'CA', 'USA', '2345678901'),
    ('Alice Johnson', 'Chicago', 'IL', 'USA', '3456789012'),
    ('Bob Brown', 'Houston', 'TX', 'USA', '4567890123'),
    ('Charlie Davis', 'Phoenix', 'AZ', 'USA', '5678901234'),
    ('Diana Evans', 'Philadelphia', 'PA', 'USA', '6789012345'),
    ('Edward Ford', 'San Antonio', 'TX', 'USA', '7890123456'),
    ('Fiona Gray', 'San Diego', 'CA', 'USA', '8901234567'),
    ('George Harris', 'Dallas', 'TX', 'USA', '9012345678'),
    ('Hannah Irving', 'San Jose', 'CA', 'USA', '0123456789'),
    # Italian customers
    ('Marco Rossi', 'Rome', 'Lazio', 'Italy', '3901234567'),
    ('Giulia Bianchi', 'Milan', 'Lombardy', 'Italy', '3909876543'),
    ('Luca Verdi', 'Florence', 'Tuscany', 'Italy', '3905678901'),
    ('Sofia Russo', 'Venice', 'Veneto', 'Italy', '3902345678')
]

# Insert CUSTOMER data
cursor.executemany("INSERT INTO CUSTOMER VALUES (?, ?, ?, ?, ?)", customers)

# Sample data for PRODUCT (including type A products)
products = [
    ('P001', 10.99, 'Electronics', 100),
    ('P002', 15.99, 'Books', 200),
    ('P003', 5.99, 'Groceries', 500),
    ('P004', 20.99, 'Clothing', 150),
    ('P005', 8.99, 'Home & Kitchen', 300),
    ('P006', 12.99, 'Sports', 120),
    ('P007', 6.99, 'Beauty', 250),
    ('P008', 18.99, 'Toys', 180),
    ('P009', 9.99, 'Office Supplies', 400),
    ('P010', 25.99, 'Furniture', 80),
    # Type A products
    ('A001', 30.99, 'A', 50),
    ('A002', 45.99, 'A', 75),
    ('A003', 22.99, 'A', 100)
]

# Insert PRODUCT data
cursor.executemany("INSERT INTO PRODUCT VALUES (?, ?, ?, ?)", products)

# Generate PURCHASE data
purchases = []
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 12, 31)
for _ in range(120):  # Generate 120 purchases
    customer = random.choice(customers)
    product = random.choice(products)
    purchase_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    purchases.append((customer[0], customer[1], purchase_date.strftime('%Y-%m-%d'), product[0]))

# Ensure some type A products are purchased
type_a_products = [p for p in products if p[2] == 'A']
for _ in range(20):  # Add 20 purchases of type A products
    customer = random.choice(customers)
    product = random.choice(type_a_products)
    purchase_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    purchases.append((customer[0], customer[1], purchase_date.strftime('%Y-%m-%d'), product[0]))

# Insert PURCHASE data
cursor.executemany("INSERT INTO PURCHASE VALUES (?, ?, ?, ?)", purchases)

# Commit the changes
conn.commit()

# Verify data insertion
print("CUSTOMER table:")
cursor.execute("SELECT * FROM CUSTOMER")
for row in cursor.fetchall():
    print(row)

print("\nPRODUCT table:")
cursor.execute("SELECT * FROM PRODUCT")
for row in cursor.fetchall():
    print(row)

print("\nPURCHASE table:")
cursor.execute("SELECT * FROM PURCHASE")
for row in cursor.fetchall():
    print(row)

# Close the connection
conn.close()
# Out:
# CUSTOMER table:
# ('John Doe', 'New York', 'NY', 'USA', '1234567890')
# ('Jane Smith', 'Los Angeles', 'CA', 'USA', '2345678901')
# ('Alice Johnson', 'Chicago', 'IL', 'USA', '3456789012')
# ('Bob Brown', 'Houston', 'TX', 'USA', '4567890123')
# ('Charlie Davis', 'Phoenix', 'AZ', 'USA', '5678901234')
# ('Diana Evans', 'Philadelphia', 'PA', 'USA', '6789012345')
# ('Edward Ford', 'San Antonio', 'TX', 'USA', '7890123456')
# ('Fiona Gray', 'San Diego', 'CA', 'USA', '8901234567')
# ('George Harris', 'Dallas', 'TX', 'USA', '9012345678')
# ('Hannah Irving', 'San Jose', 'CA', 'USA', '0123456789')
# ('Marco Rossi', 'Rome', 'Lazio', 'Italy', '3901234567')
# ('Giulia Bianchi', 'Milan', 'Lombardy', 'Italy', '3909876543')
# ('Luca Verdi', 'Florence', 'Tuscany', 'Italy', '3905678901')
# ('Sofia Russo', 'Venice', 'Veneto', 'Italy', '3902345678')
#
# PRODUCT table:
# ('P001', 10.99, 'Electronics', 100)
# ('P002', 15.99, 'Books', 200)
# ('P003', 5.99, 'Groceries', 500)
# ('P004', 20.99, 'Clothing', 150)
# ('P005', 8.99, 'Home & Kitchen', 300)
# ('P006', 12.99, 'Sports', 120)
# ('P007', 6.99, 'Beauty', 250)
# ('P008', 18.99, 'Toys', 180)
# ('P009', 9.99, 'Office Supplies', 400)
# ('P010', 25.99, 'Furniture', 80)
# ('A001', 30.99, 'A', 50)
# ('A002', 45.99, 'A', 75)
# ('A003', 22.99, 'A', 100)
#
# PURCHASE table:
# ('Giulia Bianchi', 'Milan', '2023-06-28', 'A003')
# ('Fiona Gray', 'San Diego', '2023-06-14', 'P005')
# ('Hannah Irving', 'San Jose', '2023-02-19', 'P009')
# ('George Harris', 'Dallas', '2023-12-24', 'P009')
# ('Diana Evans', 'Philadelphia', '2023-06-14', 'P005')
# ('Diana Evans', 'Philadelphia', '2023-04-01', 'P006')
# ('John Doe', 'New York', '2023-06-16', 'P003')
# ('Fiona Gray', 'San Diego', '2023-11-20', 'P008')
# ('Luca Verdi', 'Florence', '2023-08-08', 'A003')
# ('Diana Evans', 'Philadelphia', '2023-07-22', 'P004')
# ('Marco Rossi', 'Rome', '2023-10-19', 'P010')
# ('Charlie Davis', 'Phoenix', '2023-11-15', 'P001')
# ('Alice Johnson', 'Chicago', '2023-12-16', 'P007')
# ('Hannah Irving', 'San Jose', '2023-02-24', 'A003')
# ('George Harris', 'Dallas', '2023-05-13', 'P007')
# ('Giulia Bianchi', 'Milan', '2023-12-23', 'P001')
# ('Luca Verdi', 'Florence', '2023-05-19', 'P010')
# ('Jane Smith', 'Los Angeles', '2023-09-02', 'P010')
# ('George Harris', 'Dallas', '2023-09-03', 'P006')
# ('Fiona Gray', 'San Diego', '2023-01-17', 'P002')
# ('Diana Evans', 'Philadelphia', '2023-09-05', 'P009')
# ('Jane Smith', 'Los Angeles', '2023-02-09', 'P001')
# ('Diana Evans', 'Philadelphia', '2023-02-23', 'A003')
# ('Diana Evans', 'Philadelphia', '2023-01-21', 'P010')
# ('Charlie Davis', 'Phoenix', '2023-02-01', 'P004')
# ('Sofia Russo', 'Venice', '2023-01-04', 'P010')
# ('Luca Verdi', 'Florence', '2023-11-05', 'P005')
# ('John Doe', 'New York', '2023-10-25', 'A003')
# ('George Harris', 'Dallas', '2023-07-31', 'P009')
# ('Charlie Davis', 'Phoenix', '2023-06-03', 'A003')
# ('Alice Johnson', 'Chicago', '2023-02-11', 'P007')
# ('George Harris', 'Dallas', '2023-07-09', 'P006')
# ('Sofia Russo', 'Venice', '2023-01-14', 'P009')
# ('Fiona Gray', 'San Diego', '2023-12-29', 'P009')
# ('Fiona Gray', 'San Diego', '2023-06-29', 'P010')
# ('Hannah Irving', 'San Jose', '2023-06-25', 'P010')
# ('Alice Johnson', 'Chicago', '2023-08-07', 'A002')
# ('Fiona Gray', 'San Diego', '2023-12-10', 'P008')
# ('Diana Evans', 'Philadelphia', '2023-11-19', 'P008')
# ('Hannah Irving', 'San Jose', '2023-05-25', 'A002')
# ('Diana Evans', 'Philadelphia', '2023-02-20', 'P007')
# ('Alice Johnson', 'Chicago', '2023-04-01', 'A002')
# ('Edward Ford', 'San Antonio', '2023-05-30', 'P004')
# ('Giulia Bianchi', 'Milan', '2023-01-17', 'A002')
# ('Bob Brown', 'Houston', '2023-10-19', 'P010')
# ('Jane Smith', 'Los Angeles', '2023-04-12', 'P007')
# ('Giulia Bianchi', 'Milan', '2023-06-18', 'P001')
# ('Charlie Davis', 'Phoenix', '2023-07-19', 'P006')
# ('Luca Verdi', 'Florence', '2023-11-09', 'P002')
# ('George Harris', 'Dallas', '2023-07-26', 'P005')
# ('George Harris', 'Dallas', '2023-06-25', 'P007')
# ('Giulia Bianchi', 'Milan', '2023-03-24', 'P002')
# ('Hannah Irving', 'San Jose', '2023-11-18', 'P005')
# ('Hannah Irving', 'San Jose', '2023-09-12', 'P005')
# ('Bob Brown', 'Houston', '2023-03-09', 'A001')
# ('Diana Evans', 'Philadelphia', '2023-08-07', 'P009')
# ('Alice Johnson', 'Chicago', '2023-06-17', 'A001')
# ('Sofia Russo', 'Venice', '2023-02-28', 'A002')
# ('Luca Verdi', 'Florence', '2023-02-26', 'A003')
# ('Alice Johnson', 'Chicago', '2023-04-16', 'P009')
# ('Giulia Bianchi', 'Milan', '2023-11-17', 'P006')
# ('Giulia Bianchi', 'Milan', '2023-02-14', 'A001')
# ('Charlie Davis', 'Phoenix', '2023-07-07', 'P003')
# ('Fiona Gray', 'San Diego', '2023-07-07', 'P004')
# ('Sofia Russo', 'Venice', '2023-05-30', 'P002')
# ('Fiona Gray', 'San Diego', '2023-02-25', 'A001')
# ('Charlie Davis', 'Phoenix', '2023-10-01', 'P002')
# ('Edward Ford', 'San Antonio', '2023-12-28', 'P001')
# ('Hannah Irving', 'San Jose', '2023-05-04', 'P006')
# ('Luca Verdi', 'Florence', '2023-09-04', 'P001')
# ('Diana Evans', 'Philadelphia', '2023-03-15', 'P007')
# ('Edward Ford', 'San Antonio', '2023-10-27', 'P010')
# ('Charlie Davis', 'Phoenix', '2023-01-03', 'P003')
# ('Giulia Bianchi', 'Milan', '2023-05-03', 'P010')
# ('Edward Ford', 'San Antonio', '2023-11-09', 'A001')
# ('Diana Evans', 'Philadelphia', '2023-06-16', 'P003')
# ('John Doe', 'New York', '2023-09-04', 'A001')
# ('Fiona Gray', 'San Diego', '2023-05-29', 'P008')
# ('Sofia Russo', 'Venice', '2023-02-16', 'P010')
# ('Giulia Bianchi', 'Milan', '2023-08-24', 'P001')
# ('Giulia Bianchi', 'Milan', '2023-09-07', 'P009')
# ('Fiona Gray', 'San Diego', '2023-11-03', 'A002')
# ('Sofia Russo', 'Venice', '2023-04-15', 'A003')
# ('Diana Evans', 'Philadelphia', '2023-08-27', 'A002')
# ('Hannah Irving', 'San Jose', '2023-09-18', 'A002')
# ('Marco Rossi', 'Rome', '2023-06-14', 'P008')
# ('Giulia Bianchi', 'Milan', '2023-06-02', 'P007')
# ('Charlie Davis', 'Phoenix', '2023-04-20', 'A001')
# ('Luca Verdi', 'Florence', '2023-04-27', 'P001')
# ('Giulia Bianchi', 'Milan', '2023-05-03', 'P009')
# ('Luca Verdi', 'Florence', '2023-12-15', 'A001')
# ('Marco Rossi', 'Rome', '2023-11-05', 'P001')
# ('Alice Johnson', 'Chicago', '2023-12-19', 'P006')
# ('Marco Rossi', 'Rome', '2023-08-02', 'P002')
# ('Giulia Bianchi', 'Milan', '2023-12-12', 'A003')
# ('Giulia Bianchi', 'Milan', '2023-01-14', 'A002')
# ('Giulia Bianchi', 'Milan', '2023-10-30', 'P010')
# ('Bob Brown', 'Houston', '2023-05-12', 'P010')
# ('Bob Brown', 'Houston', '2023-06-13', 'A002')
# ('Sofia Russo', 'Venice', '2023-06-09', 'P009')
# ('Bob Brown', 'Houston', '2023-11-30', 'P001')
# ('Hannah Irving', 'San Jose', '2023-09-30', 'P008')
# ('Marco Rossi', 'Rome', '2023-09-05', 'P005')
# ('John Doe', 'New York', '2023-12-09', 'P007')
# ('John Doe', 'New York', '2023-10-23', 'P006')
# ('Luca Verdi', 'Florence', '2023-04-13', 'P007')
# ('Edward Ford', 'San Antonio', '2023-03-24', 'A003')
# ('Marco Rossi', 'Rome', '2023-12-05', 'A002')
# ('Hannah Irving', 'San Jose', '2023-09-01', 'P006')
# ('Sofia Russo', 'Venice', '2023-12-14', 'P010')
# ('Charlie Davis', 'Phoenix', '2023-01-20', 'P006')
# ('Fiona Gray', 'San Diego', '2023-12-12', 'P010')
# ('Edward Ford', 'San Antonio', '2023-10-30', 'P003')
# ('Luca Verdi', 'Florence', '2023-01-11', 'A001')
# ('Bob Brown', 'Houston', '2023-04-14', 'A001')
# ('Giulia Bianchi', 'Milan', '2023-01-01', 'P001')
# ('Charlie Davis', 'Phoenix', '2023-08-26', 'A003')
# ('George Harris', 'Dallas', '2023-03-10', 'P004')
# ('Bob Brown', 'Houston', '2023-07-28', 'P010')
# ('Jane Smith', 'Los Angeles', '2023-12-28', 'P010')
# ('Sofia Russo', 'Venice', '2023-12-04', 'A003')
# ('Luca Verdi', 'Florence', '2023-10-27', 'A001')
# ('Diana Evans', 'Philadelphia', '2023-06-27', 'A003')
# ('Sofia Russo', 'Venice', '2023-11-11', 'A002')
# ('Sofia Russo', 'Venice', '2023-12-23', 'A002')
# ('Alice Johnson', 'Chicago', '2023-03-22', 'A001')
# ('Charlie Davis', 'Phoenix', '2023-01-23', 'A002')
# ('Sofia Russo', 'Venice', '2023-12-29', 'A002')
# ('Bob Brown', 'Houston', '2023-09-02', 'A001')
# ('John Doe', 'New York', '2023-01-18', 'A003')
# ('Bob Brown', 'Houston', '2023-09-19', 'A003')
# ('Diana Evans', 'Philadelphia', '2023-05-11', 'A001')
# ('Marco Rossi', 'Rome', '2023-05-19', 'A003')
# ('Hannah Irving', 'San Jose', '2023-12-24', 'A001')
# ('Giulia Bianchi', 'Milan', '2023-08-25', 'A002')
# ('Marco Rossi', 'Rome', '2023-02-10', 'A002')
# ('Sofia Russo', 'Venice', '2023-08-28', 'A003')
# ('George Harris', 'Dallas', '2023-08-22', 'A001')
# ('Luca Verdi', 'Florence', '2023-08-29', 'A001')
# ('Alice Johnson', 'Chicago', '2023-07-24', 'A003')

# %%
# Connect to SQLite database (creates a new database if it doesn't exist)
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# Add new customers from Modena
modena_customers = [
    ('Renato Ferretti', 'Modena', 'Emilia-Romagna', 'Italy', '3901122334'),
    ('Stanis La Rochelle', 'Modena', 'Emilia-Romagna', 'Italy', '3904455667'),
    ('Mariano Giusti', 'Modena', 'Emilia-Romagna', 'Italy', '3907788990')
]

# Insert new Modena customers
cursor.executemany("INSERT OR IGNORE INTO CUSTOMER VALUES (?, ?, ?, ?, ?)", modena_customers)

# Get all products for random selection
cursor.execute("SELECT PROD_CODE FROM PRODUCT")
all_products = [row[0] for row in cursor.fetchall()]

# Generate purchases for Modena customers
modena_purchases = []
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 12, 31)

for customer in modena_customers:
    for _ in range(5):  # Each Modena customer makes 5 purchases
        product = random.choice(all_products)
        purchase_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
        modena_purchases.append((customer[0], customer[1], purchase_date.strftime('%Y-%m-%d'), product))

# Insert Modena purchases
cursor.executemany("INSERT INTO PURCHASE VALUES (?, ?, ?, ?)", modena_purchases)

# Commit the changes
conn.commit()

# %%
# Connect to SQLite database
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# New unsold products to add
new_unsold_products = [
    ('U001', 35.99, 'Electronics', 50),
    ('U002', 19.99, 'Books', 100),
    ('U003', 7.99, 'Phone', 200)
]

# Insert new unsold products into the PRODUCT table
cursor.executemany("""
INSERT INTO PRODUCT (PROD_CODE, PRICE, PROD_TYPE, QUANTITY)
VALUES (?, ?, ?, ?)
""", new_unsold_products)

# Commit the changes
conn.commit()

# %%
# Connect to SQLite database
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# New customers who have never made a purchase
new_non_purchasing_customers = [
    ('Duccio Patané', 'Turin', 'Piedmont', 'Italy', '3901234567'),
    ('Sergio Vannucci', 'Bologna', 'Emilia-Romagna', 'Italy', '3909876543'),
    ('Diego Lopez', 'Madrid', '', 'Spain', '3305678901'),
    ('Arianna DellArti', 'Miami', 'FL', 'USA', '3055551234'),
    ('Corinna Negri', 'Seattle', 'WA', 'USA', '2065559876')
]

# Insert new non-purchasing customers into the CUSTOMER table
cursor.executemany("""
INSERT OR IGNORE INTO CUSTOMER (NAME, CITY, REGION, COUNTRY, PHONE)
VALUES (?, ?, ?, ?, ?)
""", new_non_purchasing_customers)

# Commit the changes
conn.commit()

# %% [markdown]
# # Queries
# ## Select the customers (all the fields) with the country ‘Italy’

# %%
# Connect to SQLite database (creates a new database if it doesn't exist)
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

print("\nCustomers from Italy:")
cursor.execute("SELECT * FROM CUSTOMER WHERE COUNTRY = 'Italy'")
italian_customers = cursor.fetchall()

# print italian_customers to datafame
df = pd.DataFrame(italian_customers, columns=['Name', 'City', 'Region', 'Country', 'Phone'])

# Close the connection
conn.close()

df
# Out:
# Customers from Italy:
#                  Name      City          Region Country       Phone
# 0         Marco Rossi      Rome           Lazio   Italy  3901234567
# 1      Giulia Bianchi     Milan        Lombardy   Italy  3909876543
# 2          Luca Verdi  Florence         Tuscany   Italy  3905678901
# 3         Sofia Russo    Venice          Veneto   Italy  3902345678
# 4     Renato Ferretti    Modena  Emilia-Romagna   Italy  3901122334
# 5  Stanis La Rochelle    Modena  Emilia-Romagna   Italy  3904455667
# 6      Mariano Giusti    Modena  Emilia-Romagna   Italy  3907788990

# %% [markdown]
# ## List the regions for which exist at least one customer

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT DISTINCT REGION
FROM CUSTOMER''')
results = cursor.fetchall()


# print results as dataframe
df = pd.DataFrame(results, columns=['Region'])


# Close the connection
conn.close()

df
# Out:
#             Region
# 0               NY
# 1               CA
# 2               IL
# 3               TX
# 4               AZ
# 5               PA
# 6            Lazio
# 7         Lombardy
# 8          Tuscany
# 9           Veneto
# 10  Emilia-Romagna

# %% [markdown]
# ## Select the customers who have made at least one purchase

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT DISTINCT CUSTOMER.*
FROM CUSTOMER
JOIN PURCHASE ON PURCHASE.CUSTOMER_NAME = CUSTOMER.NAME
AND PURCHASE.CUSTOMER_CITY = CUSTOMER.CITY
''')
## With Aliases:
# SELECT DISTINCT C.*
# FROM CUSTOMER C JOIN PURCHASE P
# ON P.CUSTOMER_NAME = C.NAME AND P.CUSTOMER_CITY = C.CITY

results = cursor.fetchall()

# print results as dataframe
print("\nCustomers who have made at least one purchase:")
df = pd.DataFrame(results, columns=['Name', 'City', 'Region', 'Country', 'Phone'])

# Close the connection
conn.close()

df
# Out:
# Customers who have made at least one purchase:
#                   Name          City          Region Country       Phone
# 0       Giulia Bianchi         Milan        Lombardy   Italy  3909876543
# 1           Fiona Gray     San Diego              CA     USA  8901234567
# 2        Hannah Irving      San Jose              CA     USA  0123456789
# 3        George Harris        Dallas              TX     USA  9012345678
# 4          Diana Evans  Philadelphia              PA     USA  6789012345
# 5             John Doe      New York              NY     USA  1234567890
# 6           Luca Verdi      Florence         Tuscany   Italy  3905678901
# 7          Marco Rossi          Rome           Lazio   Italy  3901234567
# 8        Charlie Davis       Phoenix              AZ     USA  5678901234
# 9        Alice Johnson       Chicago              IL     USA  3456789012
# 10          Jane Smith   Los Angeles              CA     USA  2345678901
# 11         Sofia Russo        Venice          Veneto   Italy  3902345678
# 12         Edward Ford   San Antonio              TX     USA  7890123456
# 13           Bob Brown       Houston              TX     USA  4567890123
# 14     Renato Ferretti        Modena  Emilia-Romagna   Italy  3901122334
# 15  Stanis La Rochelle        Modena  Emilia-Romagna   Italy  3904455667
# 16      Mariano Giusti        Modena  Emilia-Romagna   Italy  3907788990

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


# Select the customers who have purchased at least one product of type ‘A’
cursor.execute('''
SELECT DISTINCT CUSTOMER.*
FROM CUSTOMER
JOIN PURCHASE ON PURCHASE.CUSTOMER_NAME = CUSTOMER.NAME
AND PURCHASE.CUSTOMER_CITY = CUSTOMER.CITY
JOIN PRODUCT ON PRODUCT.PROD_CODE = PURCHASE.PROD_CODE
WHERE PRODUCT.PROD_TYPE = 'A'
''')

results = cursor.fetchall()

# print results as dataframe
print("\nCustomers who have purchased at least one product of type 'A':")
df = pd.DataFrame(results, columns=['Name', 'City', 'Region', 'Country', 'Phone'])

# Close the connection
conn.close()

df
# Out:
# Customers who have purchased at least one product of type 'A':
#                   Name          City          Region Country       Phone
# 0       Giulia Bianchi         Milan        Lombardy   Italy  3909876543
# 1           Luca Verdi      Florence         Tuscany   Italy  3905678901
# 2        Hannah Irving      San Jose              CA     USA  0123456789
# 3          Diana Evans  Philadelphia              PA     USA  6789012345
# 4             John Doe      New York              NY     USA  1234567890
# 5        Charlie Davis       Phoenix              AZ     USA  5678901234
# 6        Alice Johnson       Chicago              IL     USA  3456789012
# 7            Bob Brown       Houston              TX     USA  4567890123
# 8          Sofia Russo        Venice          Veneto   Italy  3902345678
# 9           Fiona Gray     San Diego              CA     USA  8901234567
# 10         Edward Ford   San Antonio              TX     USA  7890123456
# 11         Marco Rossi          Rome           Lazio   Italy  3901234567
# 12       George Harris        Dallas              TX     USA  9012345678
# 13     Renato Ferretti        Modena  Emilia-Romagna   Italy  3901122334
# 14  Stanis La Rochelle        Modena  Emilia-Romagna   Italy  3904455667
# 15      Mariano Giusti        Modena  Emilia-Romagna   Italy  3907788990

# %% [markdown]
# ## Select purchases made by customers of ‘Modena'

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# Select purchases made by customers of ‘Modena'
cursor.execute('''
SELECT *
FROM CUSTOMER
WHERE CUSTOMER.CITY = 'Modena'
''')
results = cursor.fetchall()

# print results as dataframe
print("\nPurchases made by customers of 'Modena':")
df = pd.DataFrame(results, columns=['Name', 'City', 'Region', 'Country', 'Phone'])

# Close the connection
conn.close()

df
# Out:
# Purchases made by customers of 'Modena':
#                  Name    City          Region Country       Phone
# 0     Renato Ferretti  Modena  Emilia-Romagna   Italy  3901122334
# 1  Stanis La Rochelle  Modena  Emilia-Romagna   Italy  3904455667
# 2      Mariano Giusti  Modena  Emilia-Romagna   Italy  3907788990

# %% [markdown]
# ## List purchases made by italian customers (country = ‘Italy’)

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List purchases made by italian customers (country = ‘Italy’)
cursor.execute('''
SELECT P.*
FROM CUSTOMER C
JOIN PURCHASE P ON P.CUSTOMER_NAME = C.NAME
AND P.CUSTOMER_CITY = C.CITY
WHERE C.COUNTRY = 'Italy'

''')
results = cursor.fetchall()

# print results as dataframe
print("\nPurchases made by italian customers (country = 'Italy'):")
df = pd.DataFrame(results, columns=['Customer Name', 'Customer City', 'Purchase Date', 'Product Code'])

# Close the connection
conn.close()

df
# Out:
# Purchases made by italian customers (country = 'Italy'):
#      Customer Name Customer City Purchase Date Product Code
# 0   Giulia Bianchi         Milan    2023-06-28         A003
# 1       Luca Verdi      Florence    2023-08-08         A003
# 2      Marco Rossi          Rome    2023-10-19         P010
# 3   Giulia Bianchi         Milan    2023-12-23         P001
# 4       Luca Verdi      Florence    2023-05-19         P010
# ..             ...           ...           ...          ...
# 60  Mariano Giusti        Modena    2023-07-08         A003
# 61  Mariano Giusti        Modena    2023-08-23         P009
# 62  Mariano Giusti        Modena    2023-04-10         A001
# 63  Mariano Giusti        Modena    2023-04-07         P009
# 64  Mariano Giusti        Modena    2023-09-04         P010
#
# [65 rows x 4 columns]

# %% [markdown]
# # List purchases made by italian customers (country = ‘Italy’) of products with ‘A’ type

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List purchases made by italian customers (country = ‘Italy’) of products with ‘A’ type
cursor.execute('''
SELECT P.*
FROM CUSTOMER C
JOIN PURCHASE P ON P.CUSTOMER_NAME = C.NAME
AND P.CUSTOMER_CITY = C.CITY
JOIN PRODUCT PR ON PR.PROD_CODE = P.PROD_CODE
WHERE C.COUNTRY = 'Italy' AND PR.PROD_TYPE = 'A'
''')
results = cursor.fetchall()

# print results as dataframe
print("\nPurchases made by italian customers (country = 'Italy') of products with 'A' type:")
df = pd.DataFrame(results, columns=['Customer Name', 'Customer City', 'Purchase Date', 'Product Code'])

# Close the connection
conn.close()

df
# Out:
# Purchases made by italian customers (country = 'Italy') of products with 'A' type:
#          Customer Name Customer City Purchase Date Product Code
# 0       Giulia Bianchi         Milan    2023-06-28         A003
# 1           Luca Verdi      Florence    2023-08-08         A003
# 2       Giulia Bianchi         Milan    2023-01-17         A002
# 3          Sofia Russo        Venice    2023-02-28         A002
# 4           Luca Verdi      Florence    2023-02-26         A003
# 5       Giulia Bianchi         Milan    2023-02-14         A001
# 6          Sofia Russo        Venice    2023-04-15         A003
# 7           Luca Verdi      Florence    2023-12-15         A001
# 8       Giulia Bianchi         Milan    2023-12-12         A003
# 9       Giulia Bianchi         Milan    2023-01-14         A002
# 10         Marco Rossi          Rome    2023-12-05         A002
# 11          Luca Verdi      Florence    2023-01-11         A001
# 12         Sofia Russo        Venice    2023-12-04         A003
# 13          Luca Verdi      Florence    2023-10-27         A001
# 14         Sofia Russo        Venice    2023-11-11         A002
# 15         Sofia Russo        Venice    2023-12-23         A002
# 16         Sofia Russo        Venice    2023-12-29         A002
# 17         Marco Rossi          Rome    2023-05-19         A003
# 18      Giulia Bianchi         Milan    2023-08-25         A002
# 19         Marco Rossi          Rome    2023-02-10         A002
# 20         Sofia Russo        Venice    2023-08-28         A003
# 21          Luca Verdi      Florence    2023-08-29         A001
# 22     Renato Ferretti        Modena    2023-05-03         A003
# 23     Renato Ferretti        Modena    2023-10-11         A002
# 24  Stanis La Rochelle        Modena    2023-06-12         A003
# 25      Mariano Giusti        Modena    2023-07-08         A003
# 26      Mariano Giusti        Modena    2023-04-10         A001

# %%
## List the products never sold, i.e. the products for which there are no purchases

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List the products never sold, i.e. the products for which there are no purchases
cursor.execute('''
SELECT P.*
FROM PRODUCT P
WHERE P.PROD_CODE NOT IN (
	SELECT PROD_CODE
	FROM PURCHASE )
''')
results = cursor.fetchall()

# print results as dataframe

# Close the connection
conn.close()

df
# Out:
#          Customer Name Customer City Purchase Date Product Code
# 0       Giulia Bianchi         Milan    2023-06-28         A003
# 1           Luca Verdi      Florence    2023-08-08         A003
# 2       Giulia Bianchi         Milan    2023-01-17         A002
# 3          Sofia Russo        Venice    2023-02-28         A002
# 4           Luca Verdi      Florence    2023-02-26         A003
# 5       Giulia Bianchi         Milan    2023-02-14         A001
# 6          Sofia Russo        Venice    2023-04-15         A003
# 7           Luca Verdi      Florence    2023-12-15         A001
# 8       Giulia Bianchi         Milan    2023-12-12         A003
# 9       Giulia Bianchi         Milan    2023-01-14         A002
# 10         Marco Rossi          Rome    2023-12-05         A002
# 11          Luca Verdi      Florence    2023-01-11         A001
# 12         Sofia Russo        Venice    2023-12-04         A003
# 13          Luca Verdi      Florence    2023-10-27         A001
# 14         Sofia Russo        Venice    2023-11-11         A002
# 15         Sofia Russo        Venice    2023-12-23         A002
# 16         Sofia Russo        Venice    2023-12-29         A002
# 17         Marco Rossi          Rome    2023-05-19         A003
# 18      Giulia Bianchi         Milan    2023-08-25         A002
# 19         Marco Rossi          Rome    2023-02-10         A002
# 20         Sofia Russo        Venice    2023-08-28         A003
# 21          Luca Verdi      Florence    2023-08-29         A001
# 22     Renato Ferretti        Modena    2023-05-03         A003
# 23     Renato Ferretti        Modena    2023-10-11         A002
# 24  Stanis La Rochelle        Modena    2023-06-12         A003
# 25      Mariano Giusti        Modena    2023-07-08         A003
# 26      Mariano Giusti        Modena    2023-04-10         A001

# %% [markdown]
# ## List the types of unsold products, i.e. the X types for which exists at least one product of type X which was never sold.

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List the types of unsold products, i.e. the X types for which exists at least one product of type X which was never sold.
cursor.execute('''
SELECT P.PROD_TYPE
FROM PRODUCT P
WHERE P.PROD_CODE NOT IN (
	SELECT PROD_CODE
	FROM PURCHASE )
''')
results = cursor.fetchall()

# print results as dataframe
print("\nTypes of unsold products:")
df = pd.DataFrame(results, columns=['Product Type'])

# Close the connection
conn.close()

df
# Out:
# Types of unsold products:
#   Product Type
# 0  Electronics
# 1        Books
# 2        Phone

# %% [markdown]
# ## List the unsold types, i.e. the types X for which do not exist any product of type X that was sold

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List the unsold types, i.e. the types X for which do not exist any product of type X that was sold
cursor.execute('''
SELECT PROD_TYPE
FROM PRODUCT P
WHERE PROD_TYPE NOT IN (
    SELECT P.PROD_TYPE
	FROM PRODUCT P, PURCHASE PR
	WHERE P.PROD_CODE = PR.PROD_CODE
)
''')
results = cursor.fetchall()

# alternative
# SELECT PROD_TYPE
# FROM PRODUCT X
# WHERE NOT EXISTS (
#     SELECT *
# 	FROM PRODUCT P, PURCHASE PR
# 	WHERE PR.PROD_CODE = P.PROD_CODE
# 	AND P.PROD_TYPE = X.PROD_TYPE)


# print results as dataframe
print("\nUnsold types:")
df = pd.DataFrame(results, columns=['Product Type'])

# Close the connection
conn.close()

df
# Out:
# Unsold types:
#   Product Type
# 0        Phone

# %% [markdown]
# ## List the customers who have never made a purchase

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List the customers who have never made a purchase
cursor.execute('''
SELECT DISTINCT C.*
FROM CUSTOMER C
WHERE C.NAME NOT IN (
	SELECT CUSTOMER_NAME
	FROM PURCHASE )
''')
results = cursor.fetchall()

# print results as dataframe
print("\nCustomers who have never made a purchase:")
df = pd.DataFrame(results, columns=['Name', 'City', 'Region', 'Country', 'Phone'])

# Close the connection
conn.close()

df
# Out:
# Customers who have never made a purchase:
#                Name     City          Region Country       Phone
# 0  Arianna DellArti    Miami              FL     USA  3055551234
# 1     Corinna Negri  Seattle              WA     USA  2065559876
# 2       Diego Lopez  Palermo          Sicily   Italy  3905678901
# 3     Duccio Patané    Turin        Piedmont   Italy  3901234567
# 4   Sergio Vannucci  Bologna  Emilia-Romagna   Italy  3909876543

# %% [markdown]
# ## List the names of the customers who have never made a purchase

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

# List the names of the customers who have never made a purchase
# WRONG:
cursor.execute('''
SELECT DISTINCT C.NAME
FROM CUSTOMER C
WHERE C.NAME NOT IN (
	SELECT CUSTOMER_NAME
	FROM PURCHASE )
''')
results = cursor.fetchall()

# CORRECT:
# SELECT C.NAME
# FROM CUSTOMER C
# WHERE NOT EXISTS (
# 	SELECT *
# 	FROM PURCHASE P
#     WHERE P.CUSTOMER_NAME = C.NAME
#     AND P.CUSTOMER_CITY = C.CITY)

# print results as dataframe
print("\nCustomers who have never made a purchase:")
df = pd.DataFrame(results, columns=['Name'])

# Close the connection
conn.close()

df
# Out:
# Customers who have never made a purchase:
#                Name
# 0  Arianna DellArti
# 1     Corinna Negri
# 2       Diego Lopez
# 3     Duccio Patané
# 4   Sergio Vannucci

# %% [markdown]
# ## List the countries of the customers who have never made a purchase

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT DISTINCT C.COUNTRY
FROM CUSTOMER C
WHERE NOT EXISTS (
	SELECT *
	FROM PURCHASE P
	WHERE P.CUSTOMER_NAME = C.NAME
	AND P.CUSTOMER_CITY = C.CITY
)
''')
results = cursor.fetchall()

# print results as dataframe
print("\nCountries of customers who have never made a purchase:")
df = pd.DataFrame(results, columns=['Country'])

# Close the connection
conn.close()

df
# Out:
# Countries of customers who have never made a purchase:
#   Country
# 0   Italy
# 1     USA

# %% [markdown]
# ## List the countries without purchases, i.e. the countries X for which any customer of the country X has never made a purchase.

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT C.COUNTRY
FROM CUSTOMER C
WHERE C.COUNTRY NOT IN (
	SELECT C1.COUNTRY
	FROM CUSTOMER C1, PURCHASE P
	WHERE P.CUSTOMER_NAME = C1.NAME
    AND P.CUSTOMER_CITY = C1.CITY)
''')
results = cursor.fetchall()

# print results as dataframe
print("\nCountries without purchases:")
df = pd.DataFrame(results, columns=['Country'])

# Close the connection
conn.close()

df
# Out:
# Countries without purchases:
# Empty DataFrame
# Columns: [Country]
# Index: []

# %% [markdown]
# ## List, for each customer, the total number of his purchases

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT CUSTOMER_NAME, CUSTOMER_CITY, COUNT(*) AS PURCHASES_NUM
FROM PURCHASE
GROUP BY CUSTOMER_NAME, CUSTOMER_CITY
''')
results = cursor.fetchall()

# print results as dataframe
print("\nTotal number of purchases for each customer:")
df = pd.DataFrame(results, columns=['Customer Name', 'Customer City', 'Number of Purchases'])

# Close the connection
conn.close()

df
# Out:
# Total number of purchases for each customer:
#          Customer Name Customer City  Number of Purchases
# 0        Alice Johnson       Chicago                    9
# 1            Bob Brown       Houston                    9
# 2        Charlie Davis       Phoenix                   11
# 3          Diana Evans  Philadelphia                   14
# 4          Edward Ford   San Antonio                    6
# 5           Fiona Gray     San Diego                   11
# 6        George Harris        Dallas                    9
# 7       Giulia Bianchi         Milan                   17
# 8        Hannah Irving      San Jose                   11
# 9           Jane Smith   Los Angeles                    4
# 10            John Doe      New York                    6
# 11          Luca Verdi      Florence                   12
# 12         Marco Rossi          Rome                    8
# 13      Mariano Giusti        Modena                    5
# 14     Renato Ferretti        Modena                    5
# 15         Sofia Russo        Venice                   13
# 16  Stanis La Rochelle        Modena                    5

# %% [markdown]
# ## List, for every CUSTOMER_CITY, the total number of purchases of the product with code 1001

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT CUSTOMER_CITY, COUNT(*) AS PURCHASES_NUM
FROM PURCHASE
WHERE PROD_CODE = 'A001'
GROUP BY CUSTOMER_CITY
''')
results = cursor.fetchall()

# print results as dataframe
print("\nTotal number of purchases for every CUSTOMER_CITY of the product with code 1001:")
df = pd.DataFrame(results, columns=['Customer City', 'Number of Purchases'])

# Close the connection
conn.close()

df
# Out:
# Total number of purchases for every CUSTOMER_CITY of the product with code 1001:
#    Customer City  Number of Purchases
# 0        Chicago                    2
# 1         Dallas                    1
# 2       Florence                    4
# 3        Houston                    3
# 4          Milan                    1
# 5         Modena                    1
# 6       New York                    1
# 7   Philadelphia                    1
# 8        Phoenix                    1
# 9    San Antonio                    1
# 10     San Diego                    1
# 11      San Jose                    1

# %% [markdown]
# ## List, for every Country, the total number of purchases.

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT C.COUNTRY, COUNT(*) AS PURCHASES_NUM
FROM PURCHASE P, CUSTOMER C
WHERE P.CUSTOMER_NAME = C.NAME
AND P.CUSTOMER_CITY = C.CITY
GROUP BY C.COUNTRY
''')
results = cursor.fetchall()

# print results as dataframe
print("\nTotal number of purchases for every Country:")
df = pd.DataFrame(results, columns=['Country', 'Number of Purchases'])

# Close the connection
conn.close()

df
# Out:
# Total number of purchases for every Country:
#   Country  Number of Purchases
# 0   Italy                   65
# 1     USA                   90

# %% [markdown]
# ## List, for every Country, the total number of purchases, retrieving also the countries without purchases (the results should show 0 for that countries)

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()

cursor.execute('''
SELECT C.COUNTRY, COUNT(P.CUSTOMER_NAME) AS PURCHASES_NUM
FROM CUSTOMER C
LEFT JOIN PURCHASE P ON P.CUSTOMER_NAME = C.NAME
AND P.CUSTOMER_CITY = C.CITY
GROUP BY C.COUNTRY
''')
results = cursor.fetchall()

# print results as dataframe
print("\nTotal number of purchases for every Country, including countries without purchases:")
df = pd.DataFrame(results, columns=['Country', 'Number of Purchases'])

# Close the connection
conn.close()

df
# Out:
# Total number of purchases for every Country, including countries without purchases:
#   Country  Number of Purchases
# 0   Italy                   65
# 1   Spain                    0
# 2     USA                   90

# %% [markdown]
# ## List CUSTOMER_NAME and CUSTOMER_CITY of the customers with more than 2 purchases

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT CUSTOMER_NAME, CUSTOMER_CITY
FROM PURCHASE
GROUP BY CUSTOMER_NAME, CUSTOMER_CITY
HAVING COUNT(*) > 2
''')
results = cursor.fetchall()

# print results as dataframe
print("\nCustomers with more than 2 purchases:")
df = pd.DataFrame(results, columns=['Customer Name', 'Customer City'])

# Close the connection
conn.close()

df
# Out:
# Customers with more than 2 purchases:
#          Customer Name Customer City
# 0        Alice Johnson       Chicago
# 1            Bob Brown       Houston
# 2        Charlie Davis       Phoenix
# 3          Diana Evans  Philadelphia
# 4          Edward Ford   San Antonio
# 5           Fiona Gray     San Diego
# 6        George Harris        Dallas
# 7       Giulia Bianchi         Milan
# 8        Hannah Irving      San Jose
# 9           Jane Smith   Los Angeles
# 10            John Doe      New York
# 11          Luca Verdi      Florence
# 12         Marco Rossi          Rome
# 13      Mariano Giusti        Modena
# 14     Renato Ferretti        Modena
# 15         Sofia Russo        Venice
# 16  Stanis La Rochelle        Modena

# %% [markdown]
# ## List the countries with a total number of purchases (i.e. the purchases made by the customers of that country) higher than 3

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT C.COUNTRY
FROM PURCHASE P, CUSTOMER C
WHERE P.CUSTOMER_NAME = C.NAME
AND P.CUSTOMER_CITY = C.CITY
GROUP BY C.COUNTRY
HAVING COUNT(*) > 3
''')
results = cursor.fetchall()

# print results as dataframe
print("\nCountries with a total number of purchases higher than 3:")
df = pd.DataFrame(results, columns=['Country'])

# Close the connection
conn.close()

df
# Out:
# Countries with a total number of purchases higher than 3:
#   Country
# 0   Italy
# 1     USA

# %% [markdown]
# ## List the type of the most expensive product

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT PROD_TYPE
FROM PRODUCT
WHERE PRICE = (
	SELECT MAX(PRICE)
	FROM PRODUCT
)
''')
results = cursor.fetchall()

# print results as dataframe
print("\nType of the most expensive product:")
df = pd.DataFrame(results, columns=['Product Type'])

# Close the connection
conn.close()

df
# Out:
# Type of the most expensive product:
#   Product Type
# 0            A

# %% [markdown]
# ## List, for every product type, the quantity of the most expensive product

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT P.PROD_TYPE, P.QUANTITY
FROM PRODUCT P
WHERE P.PRICE = (
	SELECT MAX(P1.PRICE)
	FROM PRODUCT P1
	WHERE P1.PROD_TYPE = P.PROD_TYPE
)
''')
results = cursor.fetchall()

# print results as dataframe
print("\nQuantity of the most expensive product for every product type:")
df = pd.DataFrame(results, columns=['Product Type', 'Quantity'])

# Close the connection
conn.close()

df
# Out:
# Quantity of the most expensive product for every product type:
#        Product Type  Quantity
# 0         Groceries       500
# 1          Clothing       150
# 2    Home & Kitchen       300
# 3            Sports       120
# 4            Beauty       250
# 5              Toys       180
# 6   Office Supplies       400
# 7         Furniture        80
# 8                 A        75
# 9       Electronics        50
# 10            Books       100
# 11            Phone       200

# %% [markdown]
# ## List, for every PURCHASE_DATE, the customer (name and city) who purchased the most expensive product

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''
SELECT PR.PURCHASE_DATE, PR.CUSTOMER_NAME, PR.CUSTOMER_CITY
FROM PURCHASE PR, PRODUCT P
WHERE PR.PROD_CODE = P.PROD_CODE
AND P.PRICE = (
	SELECT MAX(P1.PRICE)
	FROM PURCHASE PR1, PRODUCT P1
	WHERE PR1.PROD_CODE = P1.PROD_CODE
	AND PR1.PURCHASE_DATE = PR.PURCHASE_DATE
)
''')
results = cursor.fetchall()

# print results as dataframe
print("\nCustomer (name and city) who purchased the most expensive product for every PURCHASE_DATE:")
df = pd.DataFrame(results, columns=['Purchase Date', 'Customer Name', 'Customer City'])

# Close the connection
conn.close()

df
# Out:
# Customer (name and city) who purchased the most expensive product for every PURCHASE_DATE:
#     Purchase Date       Customer Name Customer City
# 0      2023-06-28      Giulia Bianchi         Milan
# 1      2023-02-19       Hannah Irving      San Jose
# 2      2023-06-16            John Doe      New York
# 3      2023-11-20          Fiona Gray     San Diego
# 4      2023-08-08          Luca Verdi      Florence
# ..            ...                 ...           ...
# 122    2023-06-12  Stanis La Rochelle        Modena
# 123    2023-07-08      Mariano Giusti        Modena
# 124    2023-08-23      Mariano Giusti        Modena
# 125    2023-04-10      Mariano Giusti        Modena
# 126    2023-04-07      Mariano Giusti        Modena
#
# [127 rows x 3 columns]

# %% [markdown]
# # CTE
# Definition: A Common Table Expression (**CTE**) is a temporary result set that can be referenced within a SELECT, INSERT, UPDATE, or DELETE statement. It simplifies complex queries by breaking them into smaller, manageable parts. CTEs are particularly useful for improving readability, managing recursive queries, and organizing subqueries in a structured manner.
#
# Structure: A CTE is defined using the WITH keyword, followed by the CTE name and a query that returns a result set. It can then be referenced within the main query.
#
# Syntax:
# ```
# WITH cte_name AS (
#     -- SQL Query
# )
# SELECT * FROM cte_name;
# ```
#
# ## Write a CTE to list the total number of purchases made by each customer in Italy.

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


query = '''
WITH Italian_Customers AS (
    SELECT NAME, CITY
    FROM CUSTOMER
    WHERE COUNTRY = 'Italy'
)
SELECT IC.NAME, COUNT(P.PURCHASE_DATE) AS total_purchases
FROM Italian_Customers IC
JOIN PURCHASE P
ON IC.NAME = P.CUSTOMER_NAME AND IC.CITY = P.CUSTOMER_CITY
GROUP BY IC.NAME;
'''

# Execute the query
cursor.execute(query)

results = cursor.fetchall()

# print results as dataframe
print("\nTotal number of purchases made by each customer in Italy:")
df = pd.DataFrame(results, columns=['Customer Name', 'Total Purchases'])

# Close the connection
conn.close()

df
# Out:
# Total number of purchases made by each customer in Italy:
#         Customer Name  Total Purchases
# 0      Giulia Bianchi               17
# 1          Luca Verdi               12
# 2         Marco Rossi                8
# 3      Mariano Giusti                5
# 4     Renato Ferretti                5
# 5         Sofia Russo               13
# 6  Stanis La Rochelle                5

# %%
conn = sqlite3.connect('sample_db.sqlite')
cursor = conn.cursor()


cursor.execute('''

)
''')
results = cursor.fetchall()

# print results as dataframe


# Close the connection
conn.close()

df
